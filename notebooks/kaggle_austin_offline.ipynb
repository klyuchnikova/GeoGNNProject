# %% [markdown]
# # Austin Graph-Flashback — full offline Kaggle suite
# Clone the repository once with Internet enabled. All cells below work with Internet disabled.

# %%
# %cd /kaggle/working/GeoGNNProject
# !python scripts/check_offline_environment.py
# !python scripts/install_austin_dataset.py
# !python scripts/verify_merge.py

# %%
import torch
print("CUDA:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU")

# %% [markdown]
# ## Optional smoke test

# %%
# !python scripts/make_synthetic_data.py
# !python -m flashback.pipeline --config configs/smoke.yaml --stage all
# !python -m pytest -q --basetemp=/kaggle/working/pytest_tmp

# %% [markdown]
# ## Full resumable experiment suite

# %%
# !python scripts/run_austin_experiments.py --profile full

# %%
import pandas as pd
summary=pd.read_csv("runs/summary/experiment_metrics.csv")
display(summary)
seed_summary=pd.read_csv("runs/summary/seed_summary.csv")
display(seed_summary)

# %% [markdown]
# ## Package and download results

# %%
# !python scripts/package_results.py
from IPython.display import FileLink, display
display(FileLink("/kaggle/working/graph_flashback_austin_experiments.zip", result_html_prefix="Download results: "))
